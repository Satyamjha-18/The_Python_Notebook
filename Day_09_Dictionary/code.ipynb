# %% [markdown]
# ### Dictionary

# %%
student =['sanya',22,91.5,'bhopal']

# %%
# syntax: variable name { key,value}

# %%
# same information 

student= {
    "name": "Sanya",
    "age":22,
    "CGPA": 9.2,
    "city": "bhopal"
}

# %%
student
# Out:
# {'name': 'Sanya', 'age': 22, 'CGPA': 9.2, 'city': 'bhopal'}

# %%
type(student)
# Out:
# dict

# %% [markdown]
# ##### * In Dictionary no concept of indexing

# %%
student['name'] # axis the crosspnding value
# Out:
# 'Sanya'

# %%
student['CGPA']
# Out:
# 9.2

# %%
# update the key value

student["age"]=23

# %%
# updated dictionary
print(student)
# Out:
# {'name': 'Sanya', 'age': 23, 'CGPA': 9.2, 'city': 'bhopal'}

# %%
# insert key value pair

student["state"]="MP"

# %%
print(student)
# Out:
# {'name': 'Sanya', 'age': 23, 'CGPA': 9.2, 'city': 'bhopal', 'state': 'MP'}

# %%
student['age']
# Out:
# 23

# %%
#student["adress"] : error dega kyu ki ye kry dict me present nhi hai

# %%
student.get("age")
# Out:
# 23

# %%
student.get('address') # ye code error nhi none print kr dega

# %%
student.get('adress','key not found!')
# Out:
# 'key not found!'

# %%
student.get('age','key not found!')
# Out:
# 23

# %%
# remove the key in dictionar

student.pop('state')
# Out:
# 'MP'

# %%
student
# Out:
# {'name': 'Sanya', 'age': 23, 'CGPA': 9.2, 'city': 'bhopal'}

# %% [markdown]
# ##### how to itrate the dictionaries

# %%
student
# Out:
# {'name': 'Sanya', 'age': 23, 'CGPA': 9.2, 'city': 'bhopal'}

# %%
for i in student:
    print(i)
# Out:
# name
# age
# CGPA
# city

# %%
for i in student.keys():
    print(i)
# Out:
# name
# age
# CGPA
# city

# %%
for i in student.keys():
    print(student[i])
# Out:
# Sanya
# 23
# 9.2
# bhopal

# %%
for i in student.values():
    print(i)
# Out:
# Sanya
# 23
# 9.2
# bhopal

# %%
for elem in student.items():
    print(elem)
# Out:
# ('name', 'Sanya')
# ('age', 23)
# ('CGPA', 9.2)
# ('city', 'bhopal')

# %%
for elem in student.items():
    print("key = ",elem[0],",value=",elem[1])
# Out:
# key =  name ,value= Sanya
# key =  age ,value= 23
# key =  CGPA ,value= 9.2
# key =  city ,value= bhopal

# %%
student ={
    "name": "rahul",
    "age":22
}

# %%
print(student["name"])
# Out:
# rahul

# %%
print(student["age"])
# Out:
# 22

# %%
print(len(student))
# Out:
# 2

# %%
marks ={
    "math": 90,
    "scidence": 80,
    "English": 96
}
total =0
for subject in marks.keys():
    total+= marks[subject]

print(total)
# Out:
# 266

# %%
student={
    'name': "rahul",
    'age': 20

}
count=0
for key in student.keys():
    count+=1
print(count)
# Out:
# 2

# %%
student
# Out:
# {'name': 'rahul', 'age': 20}

# %%
student={
    'name': "rahul",
    'age': 20,
    'city': 'bhopal'

}
for key in student:
    print(len(key))
# Out:
# 4
# 3
# 4

# %%
print(student)
# Out:
# {'name': 'rahul', 'age': 20, 'city': 'bhopal'}

# %%
for item in student.items():
    print(item)
# Out:
# ('name', 'rahul')
# ('age', 20)
# ('city', 'bhopal')

# %%
fruit = {
    "Apple":50,
    "Banana":20
}

fruit["Apple"]+=fruit["Banana"]

print(fruit["Apple"])
print(fruit["Banana"])
# Out:
# 70
# 20

# %%
student ={
    "Math":90,
    "Science": 85,
    "English ":89

}
highest =0

for subject in student :
    if student[subject]>highest:
        highest=student[subject]

print(highest)
# Out:
# 90
