# %% [markdown]
# ### Error handling :
# * Exception handling ka use program ko runtime errors  se safely handle karne ke liye hota hai.

# %%
#try:
    # risky code
#except:
    # error handling

# %%
# Basic try-except
try:
    x = 10 / 0
except:
    print("Something went wrong")
# Out:
# Something went wrong

# %%
# ZeroDivisionError
try:
    num = 10
    result = num / 0

except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Cannot divide by zero

# %%
# ValueError
try:
    age = int(input("Enter age: "))
    print(age)

except ValueError:
    print("Please enter a valid number")
# Out:
# Please enter a valid number

# %%
# TypeError 
try:
    result = "10" + 5

except TypeError:
    print("Different data types cannot be added")
# Out:
# Different data types cannot be added

# %%
# FileNotFoundError
try:
    with open("abc.txt", "r") as file:
        print(file.read())

except FileNotFoundError:
    print("File does not exist")
# Out:
# File does not exist

# %%
# Multiple except Blocks
try:
    num = int(input("Enter number: "))
    result = 10 / num

except ValueError:
    print("Enter a valid number")

except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Enter a valid number

# %%
# try-except-else
try:
    num = int(input("Enter number: "))
    
except ValueError:
    print("Invalid input")

else:
    print("You entered:", num)
# Out:
# Invalid input

# %%
# finally Block
try:
    num = 10 / 2
    print(num)

except ZeroDivisionError:
    print("Cannot divide by zero")

finally:
    print("Program completed")
# Out:
# 5.0
# Program completed

# %%
# raise Keyword
age = 15

if age < 18:
    raise ValueError("Age must be 18 or above")

print("Eligible")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 5
#       2 age = 15
#       4 if age < 18:
# ----> 5     raise ValueError("Age must be 18 or above")
#       7 print("Eligible")
#
# ValueError: Age must be 18 or above

# %%
a =int(input("enter a first number"))
b=int(input("enter a second number"))
print(a)
print(b)
print(a/b)
print('hello')
# Out:
# 5
# 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 5
#       3 print(a)
#       4 print(b)
# ----> 5 print(a/b)
#       6 print('hello')
#
# ZeroDivisionError: division by zero

# %%
try:
    n = int(input())
    print(100/n)

except:
    print(n)
    print('Some error has occured')

print('hello')
# Out:
# 0
# Some error has occured
# hello

# %%
try:
    n = int(input())
    print(100/n)

except:
    print(n)
    print('Cannot divide by 0')
# Out:
# 0
# Cannot divide by 0

# %%
try:
    a=[4,5,6]
    print(a[6])

except:
    print("Invalid index")
# Out:
# Invalid index

# %% [markdown]
# ### Catching Specific Errors

# %%
try:
    n=int(input())
    print(100/n)

except Exception as e:
    print(n)
    print(e)
# Out:
# 0
# invalid literal for int() with base 10: 'aditya'

# %%
try:
    n=int(input())
    print(100/n)

except Exception as e:
    print(n)
    print(e)
# Out:
# 0
# division by zero

# %%
try:
    n=int(input())
    print(100/n)

except ZeroDivisionError :
    print(n)
    print('Division by 0 is not allowed')
except ValueError:
    print("Plaase enter number only")
# Out:
# 0
# Division by 0 is not allowed

# %%
try:
    n=int(input())
    print(100/n)

except ZeroDivisionError :
    print(n)
    print('Division by 0 is not allowed')
except ValueError:
    print(n)
    print("Plaase enter number only")
# Out:
# 0
# Plaase enter number only

# %%
try:
    n=int(input())
    print(100/n)
    a=[3,6]
    print(a[4])

except ZeroDivisionError :
    print(n)
    print('Division by 0 is not allowed')
except ValueError:
    print(n)
    print("Plaase enter number only")

except Exception as e:
    print(n)
    print('Some error has occured')
# Out:
# 20.0
# 5
# Some error has occured

# %%
try:
    n=int(input())
    print(100/n)
    a=[3,6]
    print(a[4])

except ZeroDivisionError :
    print(n)
    print('Division by 0 is not allowed')
except ValueError:
    print(n)
    print("Plaase enter number only")

except Exception as e:
    print(n)
    print('Some error has occured')
# Out:
# 5
# Plaase enter number only

# %%
# finally block always executes irrespective wether there is an error or not
try:
    num=int(input())

except ValueError:
    print("Invalid input")

else:
    print("you entered :",num)
# Out:
# you entered : 5

# %%
try:
    print(10/2)

except:
    print("Error")
# Out:
# 5.0

# %%
try:
    print(10/0)
except:
    print('Cannot devide')
# Out:
# Cannot devide

# %%
#number=[10,20,30]
#print(numbers[5]) # index error

# %%
student={
    'name':"rahul"
}
#print(student['age']) # key error

# %%
try:
    print('python')
except:
    print('error')
finally:
    print('Done')
# Out:
# python
# Done

# %%
try:
    print('python')
except:
    print('error')
else:
    print('Done')
# Out:
# python
# Done

# %%
try:
    n=int('a')
except:
    print('error')
else:
    print('Done')
# Out:
# error

# %%
try:
    a=20
    b=0
    result=a/b

    print(result)

except ZeroDivisionError:
    print("Cannot divide")

finally:
    print("program finished")
# Out:
# Cannot divide
# program finished

# %%
try:
    numbers=[5,10,15]
    index=2

    print(numbers[index])

except IndexError:
    print('wrong Index')
else:
    print("Successful")
finally:
    print('DOne')
# Out:
# 15
# Successful
# DOne

# %%
try:
    age=int("Twenty")

    print(age)

except ValueError:
    print('Invalid Age')
finally:
    print("End")
# Out:
# Invalid Age
# End

# %%
try:
    student={
        "name":"satyam",
        "marks":90
    }
    print(student["age"])

except KeyError:
    print("key Missing")

print('Program End')
# Out:
# key Missing
# Program End

# %%
try:
    marks=120

    if marks >100:
        raise ValueError("Marks Invalid")

    print(marks)

except ValueError as e:
    print(e)

print("Completed")
# Out:
# Marks Invalid
# Completed

# %%
try:
    marks=90

    if marks >100:
        raise ValueError("Marks Invalid")

    print(marks)

except ValueError as e:
    print(e)

print("Completed")
# Out:
# 90
# Completed

# %%
try:
    num=int("25")

    print(100/num)

except ValueError:
    print("Value Error")

except ZeroDivisionError:
    print("Division Error")

else:
    print("Calculation Done")
# Out:
# 4.0
# Calculation Done

# %%
try:
    numbers=[2,4,6]

    print(numbers[5])

except IndexError:
    print("Index Error")

except Exception:
    print("General Error")

finally:
    print("Finished")
# Out:
# Index Error
# Finished

# %%
try:
    value =int("50")

    print(value)

except Exception:
    print("Error")

else:
    print("Success")

finally:
    print('done')
# Out:
# 50
# Success
# done

# %%
try:
    num = int(input("Enter number: "))
    result = 100 / num

except ValueError:
    print("Invalid number")

except ZeroDivisionError:
    print("Cannot divide by zero")

else:
    print("Result:", result)

finally:
    print("Execution completed")
# Out:
# Result: 6.666666666666667
# Execution completed

# %% [markdown]
# ### file handling using a python
# * Creating ,writing and reading a text file
# * most common used type of files in aiml ->text,csv
# * Syntax : file =open(filename,mode)

# %%
name =input()
print(name)
# Out:
# satyam

# %%
file =open("sample.txt","w")
file.write("satyam\n")
file.write('rahul\n')
file.write('raj\n')
file.close()

# %%
file= open('sample.txt','r')
data=file.read()
print(data)
file.close()
# Out:
# satyam
# rahul
# raj

# %%
file= open('sample.txt','r')
data=file.readline()
print(data)
file.close()
# Out:
# satyam

# %%
file= open('sample.txt','r')
data=file.readlines()
print(data)
file.close()
# Out:
# ['satyam\n', 'rahul\n', 'raj\n', '\n', 'Mrjha\n', 'Mrjha']

# %%
for line in data:
    print(line)
# Out:
# satyam
#
# rahul
#
# raj
#
#
#
# Mrjha
#
# Mrjha

# %%
file= open('sample.txt','r')

for line in file:
    print(line)

file.close()
# Out:
# satyam
#
# rahul
#
# raj
#
#
#
# Mrjha
#
# Mrjha

# %%
file= open('sample.txt','r')

for line in file:
    print(line,end="")

file.close()
# Out:
# satyam
# rahul
# raj
#
# Mrjha
# Mrjha

# %% [markdown]
# * r -> read
# * w -> write
# * a -> append

# %%
# add a new line

file =open("sample.txt","a")
file.write("\nMrjha")
file.close()

# %%
file=open("sample.txt","r")
for line in file:
    print(line)
file.close()
# Out:
# satyam
#
# rahul
#
# raj
#
#
#
# Mrjha
#
# Mrjha
#
# Mrjha

# %%
file=open("abc.text","x")
file.close()

# %%
with open("sample.txt","r") as file:
    print(file.read())

# this is a more standard way of file handling and there is no need for closing the file.
# Out:
# satyam
# rahul
# raj
#
# Mrjha
# Mrjha
# Mrjha

# %%
with open("demo.txt","w") as file:
    file.write("sanya")

# %%
with open("demo.txt","a")as file:
    file.write("\nmrjha")

# %%
with open('demo.txt',"r")as file:
    data=file.read()

    print(data)
# Out:
# sanyamrjha
# mrjha

# %% [markdown]
# ### Handle with csv file:

# %%
import csv 

with open("student.csv",'w',newline="") as file:
    writer=csv.writer(file)
    writer.writerow(["Name","Marks","city"])
    writer.writerow(["raj","95","bhopal"])
    writer.writerow(["sanya","86","patna"])

# %%
with open("student.csv","r") as file:
    reader=csv.reader(file)

    for row in reader:
        print(row)
# Out:
# ['Name', 'Marks', 'city']
# ['raj', '95', 'bhopal']
# ['sanya', '86', 'patna']

# %%
name = input()
marks=input()
city=input()
with open("student.csv","a") as file:
    appender=
