# %% [markdown]
# # Day_02

# %% [markdown]
# ### Pythyn is case sensitive
#   * Hello & hello are both different in python

# %% [markdown]
# ### Comments(# or ctrl+/)

# %%
# this code print AJ on the screen
print("satyem")
# Out:
# satyem

# %%
# method_2 : ctrl+/ in any word
# this code print AJ on the screen
print("Aj")
# Out:
# Aj

# %% [markdown]
# # variables:

# %%
# 1. Creating Variables

name = "Satyam"
age = 22
height = 5.8
is_student = True

print(name)
print(age)
print(height)
print(is_student)
# Out:
# Satyam
# 22
# 5.8
# True

# %%
# 2. Printing Multiple Variables

name = "Satyam"
age = 22
city = "Patna"

print(name, age, city)
# Out:
# Satyam 22 Patna

# %%
# we can update the variable

collage =('lnct')
collage=('lnct_univerity')
collage
# Out:
# 'lnct_univerity'

# %%
# 4. Variable Naming Rules

student_name = "Rahul"
_age = 22
marks1 = 95

print(student_name)
print(_age)
print(marks1)
# Out:
# Rahul
# 22
# 95

# %%
# 5. Invalid Variable Names

# 1name = "Satyam"
# my-name = "Python"
# class = "A"

print("Invalid variable examples are commented.")
# Out:
# Invalid variable examples are commented.

# %%
# 6. Multiple Variable Assignment

x = y = z = 100

print(x)
print(y)
print(z)
# Out:
# 100
# 100
# 100

# %%
# 7. Multiple Values Assignment

name, age, city = "Satyam",22,"Patna"

print(name)
print(age)
print(city)
# Out:
# Satyam
# 22
# Patna

# %%
# 8. Swapping Variables

a = 10
b = 20

print("Before Swap")
print(a,b)

a,b = b,a

print("After Swap")
print(a,b)
# Out:
# Before Swap
# 10 20
# After Swap
# 20 10

# %% [markdown]
# # Datatype

# %%
# . Checking Data Types

a = 100
b = 99.99
c = "Python"
d = True

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
# 9. Numeric Data Types
integer_num = 100
float_num = 55.75
complex_num = 4+6j

print(type(integer_num))
print(type(float_num))
print(type(complex_num))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
# 10. String

language = "Python"

print(language)
print(type(language))
# Out:
# Python
# <class 'str'>

# %%
# 11. Boolean


is_login = True

print(is_login)
print(type(is_login))
# Out:
# True
# <class 'bool'>

# %%
# 12. List


fruits = ["Apple","Banana","Mango"]

print(fruits)
print(type(fruits))
# Out:
# ['Apple', 'Banana', 'Mango']
# <class 'list'>

# %%
# 13. Tuple


numbers = (10,20,30)

print(numbers)
print(type(numbers))
# Out:
# (10, 20, 30)
# <class 'tuple'>

# %%
# 14. Set


colors = {"Red","Blue","Green"}

print(colors)
print(type(colors))
# Out:
# {'Red', 'Blue', 'Green'}
# <class 'set'>

# %%
# 15. Dictionary


student = {
    "Name":"Satyam",
    "Age":22,
    "City":"Patna"
}

print(student)
print(type(student))
# Out:
# {'Name': 'Satyam', 'Age': 22, 'City': 'Patna'}
# <class 'dict'>

# %%
# 16. Type Casting


a = "100"

print(int(a))

price = 45

print(float(price))

marks = 95

print(str(marks))
# Out:
# 100
# 45.0
# 95

# %%
# 17. User Input


name = input("Enter Your Name : ")

print("Welcome",name)
# Out:
# Welcome satyam

# %%
# 18. Multiple Inputs

name = input("Enter Name : ")
age = int(input("Enter Age : "))
salary = float(input("Enter Salary : "))

print(name)
print(age)
print(salary)
# Out:
# satyam
# 21
# 10000.0

# %%
# 19. Useful Built-in Functions

print(abs(-100))
print(max(10,20,30))
print(min(10,20,30))
print(pow(2,5))
print(round(55.786,2))
# Out:
# 100
# 30
# 10
# 32
# 55.79

# %%
# 20. Memory Address


a = 10
b = 10

print(id(a))
print(id(b))
# Out:
# 1717900083728
# 1717900083728

# %%
# 21. Variable Deletion


x = 100

print(x)

del x

#print(x)
# Out:
# 100

# %%
# 22. Dynamic Typing


x = 10
print(type(x))

x = "Python"
print(type(x))

x = 5.8
print(type(x))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
# 23. Mini Practice Program


name = input("Enter Name : ")
age = int(input("Enter Age : "))
college = input("Enter College : ")

print("\n----- Student Details -----")
print("Name :",name)
print("Age :",age)
print("College :",college)
# Out:
# ----- Student Details -----
# Name : satyam
# Age : 21
# College : LNCT Univercity

# %%
# 24. Challenge Program


length = float(input("Enter Length : "))
width = float(input("Enter Width : "))

area = length * width

print("Area =",area)
# Out:
# Area = 1625.0
