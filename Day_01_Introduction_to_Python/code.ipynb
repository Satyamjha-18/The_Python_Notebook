# %% [markdown]
# # # Day 1 - Basics of Python

# %%
# 1. Print Statement


print("Hello, Python!")
print("Welcome to Day 1 of Python Learning.\n")
# Out:
# Hello, Python!
# Welcome to Day 1 of Python Learning.

# %%
# 2. Comments
# -----------------------------
# This is a single-line comment.

# %%
"""
This is a
multi-line comment.
"""
# Out:
# '\nThis is a\nmulti-line comment.\n'

# %%
# 2. Variables
name = "Satyam"
age = 21
city = "Bhopal"

# %%
# 3. Variables
# -----------------------------
name = "Satyam"
age = 21
height = 5.9
is_student = True

print("\n--- Variables ---")
print("Name:", name)
print("Age:", age)
print("Height:", height)
print("Student:", is_student)
# Out:
# --- Variables ---
# Name: Satyam
# Age: 21
# Height: 5.9
# Student: True

# %%
print("Name :", name)
print("Age  :", age)
print("City :", city)
print()
# Out:
# Name : Satyam
# Age  : 21
# City : Bhopal

# %%
# 3. Data Types
print("Data Types")
print(type(name))      # str
print(type(age))       # int
# Out:
# Data Types
# <class 'str'>
# <class 'int'>

# %%
print("Hello, Python!")

name = "Satyam"
age = 21

print(f"My name is {name}")
print(f"My age is {age}")
# Out:
# Hello, Python!
# My name is Satyam
# My age is 21

# %%
# 5. User Input
# -----------------------------
city = input("\nEnter your city: ")
print("Your city is:", city)
# Out:
# Your city is: bhopal

# %%
# -----------------------------
# 6. Multiple Variables
# -----------------------------
x, y, z = 10, 20, 30
print("\nMultiple Variables:", x, y, z)
# Out:
# Multiple Variables: 10 20 30

# %%
# -----------------------------
# 7. Variable Naming Rules
# -----------------------------
student_name = "Rahul"
_marks = 90

print(student_name)
print(_marks)

print("\nDay 1 Completed Successfully!")
# Out:
# Rahul
# 90
#
# Day 1 Completed Successfully!
